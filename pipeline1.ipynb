# %% [markdown]
# # Travel Planner Simulation Engine (Refactored)
# The codebase has been refactored into a scalable Python project structure (`models/`, `services/`, `engines/`).
# Run the cell below to trigger the simulation pipeline.

# %%
from main_simulation import run_simulation

run_simulation()
